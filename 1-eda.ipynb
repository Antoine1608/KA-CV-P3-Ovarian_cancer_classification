# %% [markdown]
# # 1 - Libraries

# %%
import pandas as pd
import numpy as np
import os
import random
import time
import matplotlib.pyplot as plt
#from PIL import Image

# %% [markdown]
# # 2 - Data Collection

# %%
df_train = pd.read_csv('/kaggle/input/UBC-OCEAN/train.csv')
df_train.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_train = pd.read_csv('/kaggle/input/UBC-OCEAN/train.csv')
#       2 df_train.head()
#
# File ~\Desktop\venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\Desktop\venv\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df_test = pd.read_csv('/kaggle/input/UBC-OCEAN/test.csv')
df_test.head()
# Out:
#    image_id  image_width  image_height
# 0        41        28469         16987

# %% [markdown]
# # 3 - Class balance

# %%
# Comptez combien de fois chaque catégorie apparaît dans la colonne 'label'
label_counts = df_train['label'].value_counts()

# Créez un pie chart en utilisant les données de 'label_counts'
plt.pie(label_counts, labels=label_counts.index, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # 4 - Image shape

# %%
# add a length/width ratio column to df
df_train['shape_ratio'] = df_train['image_width']/df_train['image_height']
# sort column shape_ratio
df_train.sort_values('shape_ratio', ascending=False)
# Out:
#      image_id label  image_width  image_height  is_tma  shape_ratio
# 46       5251  HGSC       105763         18704   False     5.654566
# 411     48973  HGSC        70020         15640   False     4.476982
# 15       1666  HGSC        69900         16083   False     4.346204
# 414     49872  LGSC        73050         16818   False     4.343560
# 382     45254    EC        62667         14444   False     4.338618
# ..        ...   ...          ...           ...     ...          ...
# 440     52438  HGSC        33243         45695   False     0.727498
# 515     62641  HGSC        16662         32055   False     0.519794
# 30       3191    CC        10688         23348   False     0.457769
# 525     63897  HGSC         9022         23582   False     0.382580
# 266     32035  HGSC        16861         44075   False     0.382552
#
# [538 rows x 6 columns]

# %%
plt.imshow(plt.imread('/kaggle/input/UBC-OCEAN/train_thumbnails/5251_thumbnail.png'))
